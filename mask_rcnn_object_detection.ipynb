# %%
# example of extracting bounding boxes from an annotation file
from xml.etree import ElementTree

# function to extract bounding boxes from an annotation file
def extract_boxes(filename):
	# load and parse the file
	tree = ElementTree.parse(filename)
	# get the root of the document
	root = tree.getroot()
	# extract each bounding box
	boxes = list()
	for box in root.findall('.//bndbox'):
		xmin = int(box.find('xmin').text)
		ymin = int(box.find('ymin').text)
		xmax = int(box.find('xmax').text)
		ymax = int(box.find('ymax').text)
		coors = [xmin, ymin, xmax, ymax]
		boxes.append(coors)
	# extract image dimensions
	width = int(root.find('.//size/width').text)
	height = int(root.find('.//size/height').text)
	return boxes, width, height

# extract details form annotation file
boxes, w, h = extract_boxes('kangaroo/annots/00001.xml')
# summarize extracted details
print(boxes, w, h)
# Out:
# [[233, 89, 386, 262], [134, 105, 341, 253]] 450 319

# %%
# split into train and test set
from os import listdir
from xml.etree import ElementTree
from numpy import zeros
from numpy import asarray
from mrcnn.utils import Dataset

# class that defines and loads the kangaroo dataset
class KangarooDataset(Dataset):
	# load the dataset definitions
	def load_dataset(self, dataset_dir, is_train=True):
		# define one class
		self.add_class("dataset", 1, "kangaroo")
		# define data locations
		images_dir = dataset_dir + '/images/'
		annotations_dir = dataset_dir + '/annots/'
		# find all images
		for filename in listdir(images_dir):
			# extract image id
			image_id = filename[:-4]
			# skip bad images
			if image_id in ['00090']:
				continue
			# skip all images after 150 if we are building the train set
			if is_train and int(image_id) >= 150:
				continue
			# skip all images before 150 if we are building the test/val set
			if not is_train and int(image_id) < 150:
				continue
			img_path = images_dir + filename
			ann_path = annotations_dir + image_id + '.xml'
			# add to dataset
			self.add_image('dataset', image_id=image_id, path=img_path, annotation=ann_path)

	# extract bounding boxes from an annotation file
	def extract_boxes(self, filename):
		# load and parse the file
		tree = ElementTree.parse(filename)
		# get the root of the document
		root = tree.getroot()
		# extract each bounding box
		boxes = list()
		for box in root.findall('.//bndbox'):
			xmin = int(box.find('xmin').text)
			ymin = int(box.find('ymin').text)
			xmax = int(box.find('xmax').text)
			ymax = int(box.find('ymax').text)
			coors = [xmin, ymin, xmax, ymax]
			boxes.append(coors)
		# extract image dimensions
		width = int(root.find('.//size/width').text)
		height = int(root.find('.//size/height').text)
		return boxes, width, height

	# load the masks for an image
	def load_mask(self, image_id):
		# get details of image
		info = self.image_info[image_id]
		# define box file location
		path = info['annotation']
		# load XML
		boxes, w, h = self.extract_boxes(path)
		# create one array for all masks, each on a different channel
		masks = zeros([h, w, len(boxes)], dtype='uint8')
		# create masks
		class_ids = list()
		for i in range(len(boxes)):
			box = boxes[i]
			row_s, row_e = box[1], box[3]
			col_s, col_e = box[0], box[2]
			masks[row_s:row_e, col_s:col_e, i] = 1
			class_ids.append(self.class_names.index('kangaroo'))
		return masks, asarray(class_ids, dtype='int32')

	# load an image reference
	def image_reference(self, image_id):
		info = self.image_info[image_id]
		return info['path']

# train set
train_set = KangarooDataset()
train_set.load_dataset('kangaroo', is_train=True)
train_set.prepare()
print('Train: %d' % len(train_set.image_ids))

# test/val set
test_set = KangarooDataset()
test_set.load_dataset('kangaroo', is_train=False)
test_set.prepare()
print('Test: %d' % len(test_set.image_ids))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Train: 131
# Test: 32

# %%
# plot one photograph and mask
from os import listdir
from xml.etree import ElementTree
from numpy import zeros
from numpy import asarray
from mrcnn.utils import Dataset
from matplotlib import pyplot

# class that defines and loads the kangaroo dataset
class KangarooDataset(Dataset):
    # load the dataset definitions
    def load_dataset(self, dataset_dir, is_train=True):
        # define one class
        self.add_class("dataset", 1, "kangaroo")
        # define data locations
        images_dir = dataset_dir + '/images/'
        annotations_dir = dataset_dir + '/annots/'
        # find all images
        for filename in listdir(images_dir):
            # extract image id
            image_id = filename[:-4]
            # skip bad images
            if image_id in ['00090']:
                continue
            # skip all images after 150 if we are building the train set
            if is_train and int(image_id) >= 150:
                continue
            # skip all images before 150 if we are building the test/val set
            if not is_train and int(image_id) < 150:
                continue
            img_path = images_dir + filename
            ann_path = annotations_dir + image_id + '.xml'
            # add to dataset
            self.add_image('dataset', image_id=image_id, path=img_path, annotation=ann_path)

    # extract bounding boxes from an annotation file
    def extract_boxes(self, filename):
        # load and parse the file
        tree = ElementTree.parse(filename)
        # get the root of the document
        root = tree.getroot()
        # extract each bounding box
        boxes = list()
        for box in root.findall('.//bndbox'):
            xmin = int(box.find('xmin').text)
            ymin = int(box.find('ymin').text)
            xmax = int(box.find('xmax').text)
            ymax = int(box.find('ymax').text)
            coors = [xmin, ymin, xmax, ymax]
            boxes.append(coors)
        # extract image dimensions
        width = int(root.find('.//size/width').text)
        height = int(root.find('.//size/height').text)
        return boxes, width, height

    # load the masks for an image
    def load_mask(self, image_id):
        # get details of image
        info = self.image_info[image_id]
        # define box file location
        path = info['annotation']
        # load XML
        boxes, w, h = self.extract_boxes(path)
        # create one array for all masks, each on a different channel
        masks = zeros([h, w, len(boxes)], dtype='uint8')
        # create masks
        class_ids = list()
        for i in range(len(boxes)):
            box = boxes[i]
            row_s, row_e = box[1], box[3]
            col_s, col_e = box[0], box[2]
            masks[row_s:row_e, col_s:col_e, i] = 1
            class_ids.append(self.class_names.index('kangaroo'))
        return masks, asarray(class_ids, dtype='int32')

    # load an image reference
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']

# train set
train_set = KangarooDataset()
train_set.load_dataset('kangaroo', is_train=True)
train_set.prepare()
# load an image
image_id = 0
image = train_set.load_image(image_id)
print(image.shape)
# load image mask
mask, class_ids = train_set.load_mask(image_id)
print(mask.shape)
# plot image
pyplot.imshow(image)
# plot mask
pyplot.imshow(mask[:, :, 0], cmap='gray', alpha=0.5)
pyplot.show()
# Out:
# (523, 960, 3)
# (523, 960, 2)

# %%
# plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# plot raw pixel data
	image = train_set.load_image(i)
	pyplot.imshow(image)
	# plot all masks
	mask, _ = train_set.load_mask(i)
	for j in range(mask.shape[2]):
		pyplot.imshow(mask[:, :, j], cmap='gray', alpha=0.3)
# show the figure
pyplot.show()

# %%
# enumerate all images in the dataset
for image_id in train_set.image_ids:
	# load image info
	info = train_set.image_info[image_id]
	# display on the console
	print(info)
# Out:
# {'id': '00086', 'source': 'dataset', 'path': 'kangaroo/images/00086.jpg', 'annotation': 'kangaroo/annots/00086.xml'}
# {'id': '00148', 'source': 'dataset', 'path': 'kangaroo/images/00148.jpg', 'annotation': 'kangaroo/annots/00148.xml'}
# {'id': '00096', 'source': 'dataset', 'path': 'kangaroo/images/00096.jpg', 'annotation': 'kangaroo/annots/00096.xml'}
# {'id': '00149', 'source': 'dataset', 'path': 'kangaroo/images/00149.jpg', 'annotation': 'kangaroo/annots/00149.xml'}
# {'id': '00046', 'source': 'dataset', 'path': 'kangaroo/images/00046.jpg', 'annotation': 'kangaroo/annots/00046.xml'}
# {'id': '00083', 'source': 'dataset', 'path': 'kangaroo/images/00083.jpg', 'annotation': 'kangaroo/annots/00083.xml'}
# {'id': '00039', 'source': 'dataset', 'path': 'kangaroo/images/00039.jpg', 'annotation': 'kangaroo/annots/00039.xml'}
# {'id': '00102', 'source': 'dataset', 'path': 'kangaroo/images/00102.jpg', 'annotation': 'kangaroo/annots/00102.xml'}
# {'id': '00043', 'source': 'dataset', 'path': 'kangaroo/images/00043.jpg', 'annotation': 'kangaroo/annots/00043.xml'}
# {'id': '00051', 'source': 'dataset', 'path': 'kangaroo/images/00051.jpg', 'annotation': 'kangaroo/annots/00051.xml'}
# {'id': '00131', 'source': 'dataset', 'path': 'kangaroo/images/00131.jpg', 'annotation': 'kangaroo/annots/00131.xml'}
# {'id': '00037', 'source': 'dataset', 'path': 'kangaroo/images/00037.jpg', 'annotation': 'kangaroo/annots/00037.xml'}
# {'id': '00023', 'source': 'dataset', 'path': 'kangaroo/images/00023.jpg', 'annotation': 'kangaroo/annots/00023.xml'}
# {'id': '00118', 'source': 'dataset', 'path': 'kangaroo/images/00118.jpg', 'annotation': 'kangaroo/annots/00118.xml'}
# {'id': '00087', 'source': 'dataset', 'path': 'kangaroo/images/00087.jpg', 'annotation': 'kangaroo/annots/00087.xml'}
# {'id': '00121', 'source': 'dataset', 'path': 'kangaroo/images/00121.jpg', 'annotation': 'kangaroo/annots/00121.xml'}
# {'id': '00071', 'source': 'dataset', 'path': 'kangaroo/images/00071.jpg', 'annotation': 'kangaroo/annots/00071.xml'}
# {'id': '00073', 'source': 'dataset', 'path': 'kangaroo/images/00073.jpg', 'annotation': 'kangaroo/annots/00073.xml'}
# {'id': '00054', 'source': 'dataset', 'path': 'kangaroo/images/00054.jpg', 'annotation': 'kangaroo/annots/00054.xml'}
# {'id': '00056', 'source': 'dataset', 'path': 'kangaroo/images/00056.jpg', 'annotation': 'kangaroo/annots/00056.xml'}
# {'id': '00145', 'source': 'dataset', 'path': 'kangaroo/images/00145.jpg', 'annotation': 'kangaroo/annots/00145.xml'}
# {'id': '00012', 'source': 'dataset', 'path': 'kangaroo/images/00012.jpg', 'annotation': 'kangaroo/annots/00012.xml'}
# {'id': '00053', 'source': 'dataset', 'path': 'kangaroo/images/00053.jpg', 'annotation': 'kangaroo/annots/00053.xml'}
# {'id': '00101', 'source': 'dataset', 'path': 'kangaroo/images/00101.jpg', 'annotation': 'kangaroo/annots/00101.xml'}
# {'id': '00006', 'source': 'dataset', 'path': 'kangaroo/images/00006.jpg', 'annotation': 'kangaroo/annots/00006.xml'}
# {'id': '00020', 'source': 'dataset', 'path': 'kangaroo/images/00020.jpg', 'annotation': 'kangaroo/annots/00020.xml'}
# {'id': '00014', 'source': 'dataset', 'path': 'kangaroo/images/00014.jpg', 'annotation': 'kangaroo/annots/00014.xml'}
# {'id': '00147', 'source': 'dataset', 'path': 'kangaroo/images/00147.jpg', 'annotation': 'kangaroo/annots/00147.xml'}
# {'id': '00132', 'source': 'dataset', 'path': 'kangaroo/images/00132.jpg', 'annotation': 'kangaroo/annots/00132.xml'}
# {'id': '00107', 'source': 'dataset', 'path': 'kangaroo/images/00107.jpg', 'annotation': 'kangaroo/annots/00107.xml'}
# {'id': '00084', 'source': 'dataset', 'path': 'kangaroo/images/00084.jpg', 'annotation': 'kangaroo/annots/00084.xml'}
# {'id': '00123', 'source': 'dataset', 'path': 'kangaroo/images/00123.jpg', 'annotation': 'kangaroo/annots/00123.xml'}
# {'id': '00018', 'source': 'dataset', 'path': 'kangaroo/images/00018.jpg', 'annotation': 'kangaroo/annots/00018.xml'}
# {'id': '00115', 'source': 'dataset', 'path': 'kangaroo/images/00115.jpg', 'annotation': 'kangaroo/annots/00115.xml'}
# {'id': '00076', 'source': 'dataset', 'path': 'kangaroo/images/00076.jpg', 'annotation': 'kangaroo/annots/00076.xml'}
# {'id': '00143', 'source': 'dataset', 'path': 'kangaroo/images/00143.jpg', 'annotation': 'kangaroo/annots/00143.xml'}
# {'id': '00032', 'source': 'dataset', 'path': 'kangaroo/images/00032.jpg', 'annotation': 'kangaroo/annots/00032.xml'}
# {'id': '00021', 'source': 'dataset', 'path': 'kangaroo/images/00021.jpg', 'annotation': 'kangaroo/annots/00021.xml'}
# {'id': '00077', 'source': 'dataset', 'path': 'kangaroo/images/00077.jpg', 'annotation': 'kangaroo/annots/00077.xml'}
# {'id': '00013', 'source': 'dataset', 'path': 'kangaroo/images/00013.jpg', 'annotation': 'kangaroo/annots/00013.xml'}
# {'id': '00042', 'source': 'dataset', 'path': 'kangaroo/images/00042.jpg', 'annotation': 'kangaroo/annots/00042.xml'}
# {'id': '00144', 'source': 'dataset', 'path': 'kangaroo/images/00144.jpg', 'annotation': 'kangaroo/annots/00144.xml'}
# {'id': '00103', 'source': 'dataset', 'path': 'kangaroo/images/00103.jpg', 'annotation': 'kangaroo/annots/00103.xml'}
# {'id': '00137', 'source': 'dataset', 'path': 'kangaroo/images/00137.jpg', 'annotation': 'kangaroo/annots/00137.xml'}
# {'id': '00109', 'source': 'dataset', 'path': 'kangaroo/images/00109.jpg', 'annotation': 'kangaroo/annots/00109.xml'}
# {'id': '00078', 'source': 'dataset', 'path': 'kangaroo/images/00078.jpg', 'annotation': 'kangaroo/annots/00078.xml'}
# {'id': '00055', 'source': 'dataset', 'path': 'kangaroo/images/00055.jpg', 'annotation': 'kangaroo/annots/00055.xml'}
# {'id': '00069', 'source': 'dataset', 'path': 'kangaroo/images/00069.jpg', 'annotation': 'kangaroo/annots/00069.xml'}
# {'id': '00075', 'source': 'dataset', 'path': 'kangaroo/images/00075.jpg', 'annotation': 'kangaroo/annots/00075.xml'}
# {'id': '00065', 'source': 'dataset', 'path': 'kangaroo/images/00065.jpg', 'annotation': 'kangaroo/annots/00065.xml'}
# {'id': '00059', 'source': 'dataset', 'path': 'kangaroo/images/00059.jpg', 'annotation': 'kangaroo/annots/00059.xml'}
# {'id': '00112', 'source': 'dataset', 'path': 'kangaroo/images/00112.jpg', 'annotation': 'kangaroo/annots/00112.xml'}
# {'id': '00091', 'source': 'dataset', 'path': 'kangaroo/images/00091.jpg', 'annotation': 'kangaroo/annots/00091.xml'}
# {'id': '00030', 'source': 'dataset', 'path': 'kangaroo/images/00030.jpg', 'annotation': 'kangaroo/annots/00030.xml'}
# {'id': '00085', 'source': 'dataset', 'path': 'kangaroo/images/00085.jpg', 'annotation': 'kangaroo/annots/00085.xml'}
# {'id': '00062', 'source': 'dataset', 'path': 'kangaroo/images/00062.jpg', 'annotation': 'kangaroo/annots/00062.xml'}
# {'id': '00074', 'source': 'dataset', 'path': 'kangaroo/images/00074.jpg', 'annotation': 'kangaroo/annots/00074.xml'}
# {'id': '00033', 'source': 'dataset', 'path': 'kangaroo/images/00033.jpg', 'annotation': 'kangaroo/annots/00033.xml'}
# {'id': '00072', 'source': 'dataset', 'path': 'kangaroo/images/00072.jpg', 'annotation': 'kangaroo/annots/00072.xml'}
# {'id': '00093', 'source': 'dataset', 'path': 'kangaroo/images/00093.jpg', 'annotation': 'kangaroo/annots/00093.xml'}
# {'id': '00119', 'source': 'dataset', 'path': 'kangaroo/images/00119.jpg', 'annotation': 'kangaroo/annots/00119.xml'}
# {'id': '00025', 'source': 'dataset', 'path': 'kangaroo/images/00025.jpg', 'annotation': 'kangaroo/annots/00025.xml'}
# {'id': '00052', 'source': 'dataset', 'path': 'kangaroo/images/00052.jpg', 'annotation': 'kangaroo/annots/00052.xml'}
# {'id': '00060', 'source': 'dataset', 'path': 'kangaroo/images/00060.jpg', 'annotation': 'kangaroo/annots/00060.xml'}
# {'id': '00041', 'source': 'dataset', 'path': 'kangaroo/images/00041.jpg', 'annotation': 'kangaroo/annots/00041.xml'}
# {'id': '00094', 'source': 'dataset', 'path': 'kangaroo/images/00094.jpg', 'annotation': 'kangaroo/annots/00094.xml'}
# {'id': '00029', 'source': 'dataset', 'path': 'kangaroo/images/00029.jpg', 'annotation': 'kangaroo/annots/00029.xml'}
# {'id': '00125', 'source': 'dataset', 'path': 'kangaroo/images/00125.jpg', 'annotation': 'kangaroo/annots/00125.xml'}
# {'id': '00040', 'source': 'dataset', 'path': 'kangaroo/images/00040.jpg', 'annotation': 'kangaroo/annots/00040.xml'}
# {'id': '00031', 'source': 'dataset', 'path': 'kangaroo/images/00031.jpg', 'annotation': 'kangaroo/annots/00031.xml'}
# {'id': '00022', 'source': 'dataset', 'path': 'kangaroo/images/00022.jpg', 'annotation': 'kangaroo/annots/00022.xml'}
# {'id': '00034', 'source': 'dataset', 'path': 'kangaroo/images/00034.jpg', 'annotation': 'kangaroo/annots/00034.xml'}
# {'id': '00097', 'source': 'dataset', 'path': 'kangaroo/images/00097.jpg', 'annotation': 'kangaroo/annots/00097.xml'}
# {'id': '00141', 'source': 'dataset', 'path': 'kangaroo/images/00141.jpg', 'annotation': 'kangaroo/annots/00141.xml'}
# {'id': '00050', 'source': 'dataset', 'path': 'kangaroo/images/00050.jpg', 'annotation': 'kangaroo/annots/00050.xml'}
# {'id': '00001', 'source': 'dataset', 'path': 'kangaroo/images/00001.jpg', 'annotation': 'kangaroo/annots/00001.xml'}
# {'id': '00111', 'source': 'dataset', 'path': 'kangaroo/images/00111.jpg', 'annotation': 'kangaroo/annots/00111.xml'}
# {'id': '00122', 'source': 'dataset', 'path': 'kangaroo/images/00122.jpg', 'annotation': 'kangaroo/annots/00122.xml'}
# {'id': '00136', 'source': 'dataset', 'path': 'kangaroo/images/00136.jpg', 'annotation': 'kangaroo/annots/00136.xml'}
# {'id': '00066', 'source': 'dataset', 'path': 'kangaroo/images/00066.jpg', 'annotation': 'kangaroo/annots/00066.xml'}
# {'id': '00100', 'source': 'dataset', 'path': 'kangaroo/images/00100.jpg', 'annotation': 'kangaroo/annots/00100.xml'}
# {'id': '00003', 'source': 'dataset', 'path': 'kangaroo/images/00003.jpg', 'annotation': 'kangaroo/annots/00003.xml'}
# {'id': '00048', 'source': 'dataset', 'path': 'kangaroo/images/00048.jpg', 'annotation': 'kangaroo/annots/00048.xml'}
# {'id': '00017', 'source': 'dataset', 'path': 'kangaroo/images/00017.jpg', 'annotation': 'kangaroo/annots/00017.xml'}
# {'id': '00044', 'source': 'dataset', 'path': 'kangaroo/images/00044.jpg', 'annotation': 'kangaroo/annots/00044.xml'}
# {'id': '00080', 'source': 'dataset', 'path': 'kangaroo/images/00080.jpg', 'annotation': 'kangaroo/annots/00080.xml'}
# {'id': '00117', 'source': 'dataset', 'path': 'kangaroo/images/00117.jpg', 'annotation': 'kangaroo/annots/00117.xml'}
# {'id': '00004', 'source': 'dataset', 'path': 'kangaroo/images/00004.jpg', 'annotation': 'kangaroo/annots/00004.xml'}
# {'id': '00019', 'source': 'dataset', 'path': 'kangaroo/images/00019.jpg', 'annotation': 'kangaroo/annots/00019.xml'}
# {'id': '00009', 'source': 'dataset', 'path': 'kangaroo/images/00009.jpg', 'annotation': 'kangaroo/annots/00009.xml'}
# {'id': '00005', 'source': 'dataset', 'path': 'kangaroo/images/00005.jpg', 'annotation': 'kangaroo/annots/00005.xml'}
# {'id': '00092', 'source': 'dataset', 'path': 'kangaroo/images/00092.jpg', 'annotation': 'kangaroo/annots/00092.xml'}
# {'id': '00016', 'source': 'dataset', 'path': 'kangaroo/images/00016.jpg', 'annotation': 'kangaroo/annots/00016.xml'}
# {'id': '00036', 'source': 'dataset', 'path': 'kangaroo/images/00036.jpg', 'annotation': 'kangaroo/annots/00036.xml'}
# {'id': '00120', 'source': 'dataset', 'path': 'kangaroo/images/00120.jpg', 'annotation': 'kangaroo/annots/00120.xml'}
# {'id': '00113', 'source': 'dataset', 'path': 'kangaroo/images/00113.jpg', 'annotation': 'kangaroo/annots/00113.xml'}
# {'id': '00027', 'source': 'dataset', 'path': 'kangaroo/images/00027.jpg', 'annotation': 'kangaroo/annots/00027.xml'}
# {'id': '00011', 'source': 'dataset', 'path': 'kangaroo/images/00011.jpg', 'annotation': 'kangaroo/annots/00011.xml'}
# {'id': '00088', 'source': 'dataset', 'path': 'kangaroo/images/00088.jpg', 'annotation': 'kangaroo/annots/00088.xml'}
# {'id': '00130', 'source': 'dataset', 'path': 'kangaroo/images/00130.jpg', 'annotation': 'kangaroo/annots/00130.xml'}
# {'id': '00139', 'source': 'dataset', 'path': 'kangaroo/images/00139.jpg', 'annotation': 'kangaroo/annots/00139.xml'}
# {'id': '00129', 'source': 'dataset', 'path': 'kangaroo/images/00129.jpg', 'annotation': 'kangaroo/annots/00129.xml'}
# {'id': '00047', 'source': 'dataset', 'path': 'kangaroo/images/00047.jpg', 'annotation': 'kangaroo/annots/00047.xml'}
# {'id': '00026', 'source': 'dataset', 'path': 'kangaroo/images/00026.jpg', 'annotation': 'kangaroo/annots/00026.xml'}
# {'id': '00024', 'source': 'dataset', 'path': 'kangaroo/images/00024.jpg', 'annotation': 'kangaroo/annots/00024.xml'}
# {'id': '00099', 'source': 'dataset', 'path': 'kangaroo/images/00099.jpg', 'annotation': 'kangaroo/annots/00099.xml'}
# {'id': '00079', 'source': 'dataset', 'path': 'kangaroo/images/00079.jpg', 'annotation': 'kangaroo/annots/00079.xml'}
# {'id': '00028', 'source': 'dataset', 'path': 'kangaroo/images/00028.jpg', 'annotation': 'kangaroo/annots/00028.xml'}
# {'id': '00038', 'source': 'dataset', 'path': 'kangaroo/images/00038.jpg', 'annotation': 'kangaroo/annots/00038.xml'}
# {'id': '00146', 'source': 'dataset', 'path': 'kangaroo/images/00146.jpg', 'annotation': 'kangaroo/annots/00146.xml'}
# {'id': '00064', 'source': 'dataset', 'path': 'kangaroo/images/00064.jpg', 'annotation': 'kangaroo/annots/00064.xml'}
# {'id': '00134', 'source': 'dataset', 'path': 'kangaroo/images/00134.jpg', 'annotation': 'kangaroo/annots/00134.xml'}
# {'id': '00098', 'source': 'dataset', 'path': 'kangaroo/images/00098.jpg', 'annotation': 'kangaroo/annots/00098.xml'}
# {'id': '00124', 'source': 'dataset', 'path': 'kangaroo/images/00124.jpg', 'annotation': 'kangaroo/annots/00124.xml'}
# {'id': '00095', 'source': 'dataset', 'path': 'kangaroo/images/00095.jpg', 'annotation': 'kangaroo/annots/00095.xml'}
# {'id': '00108', 'source': 'dataset', 'path': 'kangaroo/images/00108.jpg', 'annotation': 'kangaroo/annots/00108.xml'}
# {'id': '00045', 'source': 'dataset', 'path': 'kangaroo/images/00045.jpg', 'annotation': 'kangaroo/annots/00045.xml'}
# {'id': '00127', 'source': 'dataset', 'path': 'kangaroo/images/00127.jpg', 'annotation': 'kangaroo/annots/00127.xml'}
# {'id': '00089', 'source': 'dataset', 'path': 'kangaroo/images/00089.jpg', 'annotation': 'kangaroo/annots/00089.xml'}
# {'id': '00002', 'source': 'dataset', 'path': 'kangaroo/images/00002.jpg', 'annotation': 'kangaroo/annots/00002.xml'}
# {'id': '00128', 'source': 'dataset', 'path': 'kangaroo/images/00128.jpg', 'annotation': 'kangaroo/annots/00128.xml'}
# {'id': '00105', 'source': 'dataset', 'path': 'kangaroo/images/00105.jpg', 'annotation': 'kangaroo/annots/00105.xml'}
# {'id': '00110', 'source': 'dataset', 'path': 'kangaroo/images/00110.jpg', 'annotation': 'kangaroo/annots/00110.xml'}
# {'id': '00007', 'source': 'dataset', 'path': 'kangaroo/images/00007.jpg', 'annotation': 'kangaroo/annots/00007.xml'}
# {'id': '00116', 'source': 'dataset', 'path': 'kangaroo/images/00116.jpg', 'annotation': 'kangaroo/annots/00116.xml'}
# {'id': '00140', 'source': 'dataset', 'path': 'kangaroo/images/00140.jpg', 'annotation': 'kangaroo/annots/00140.xml'}
# {'id': '00061', 'source': 'dataset', 'path': 'kangaroo/images/00061.jpg', 'annotation': 'kangaroo/annots/00061.xml'}
# {'id': '00081', 'source': 'dataset', 'path': 'kangaroo/images/00081.jpg', 'annotation': 'kangaroo/annots/00081.xml'}
# {'id': '00114', 'source': 'dataset', 'path': 'kangaroo/images/00114.jpg', 'annotation': 'kangaroo/annots/00114.xml'}
# {'id': '00049', 'source': 'dataset', 'path': 'kangaroo/images/00049.jpg', 'annotation': 'kangaroo/annots/00049.xml'}
# {'id': '00010', 'source': 'dataset', 'path': 'kangaroo/images/00010.jpg', 'annotation': 'kangaroo/annots/00010.xml'}

# %%
# define image id
image_id = 1

# load the image
image = train_set.load_image(image_id)

# load the masks and the class ids
mask, class_ids = train_set.load_mask(image_id)

# %%
# extract bounding boxes from the masks
bbox = extract_bboxes(mask)
# display image with masks and bounding boxes
display_instances(image, bbox, mask, class_ids, train_set.class_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-4748433742cd> in <module>
#       1 # extract bounding boxes from the masks
# ----> 2 bbox = extract_bboxes(mask)
#       3 # display image with masks and bounding boxes
#       4 display_instances(image, bbox, mask, class_ids, train_set.class_names)
#
# NameError: name 'extract_bboxes' is not defined
